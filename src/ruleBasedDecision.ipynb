# %% [markdown]
# # Règles pour la décisions
# Pour aider à la décision de l'intelligence artificielle, un certain nombre de règles sont établient pour permettre d'être plus précis dans les cas simples.<br>
# Un certain nombre de pics sont référencés, si un de ces pic est supérieur à un seuil, le chromatogramme ne sera pas considéré comme normale, et une justification (nom de la molécule ou nom de la maladie) pourra être affichée. <br>
# Ce résultat sera là en complément de l'analyse par intelligence artificielle.

# %%
import pandas as d
from importlib import reload
import pandas as pd
import tools
reload(tools)

pd.options.plotting.backend = "plotly"
PATH = '../data/chromatograms/'

# %%
data = tools.readAllData(PATH)

# %%
# chedadi 100 acide méthylmalonique et 30H-propionique (un peu)
reload(tools)
for i in data[:4]:
    print(i.name)
    fig = i.df.plot()
    fig.show()
    print(i.ruleBasedCheck())
# Out:
# AbaziM-20200210
# [(9.426, 111.67089915769836, 'Acide 3OH-Propionique 20')]
# AbdiAA-20201012
# [(9.417, 133.74510283658137, 'Acide 3OH-Propionique 20'), (11.846, 133.74510283658137, 'Acide Methylmalonique 20'), (16.61, 264.2785742456305, 'Acide Fumarique 20200722'), (18.604, 264.2785742456305, 'Acide Glutarique 2020072'), (19.089, 264.2785742456305, 'Acide 3CH3-Glutarique 20'), (21.591, 264.2785742456305, 'Acide Adipique 20200722'), (23.705, 264.2785742456305, 'Acide 2OH-Glutarique 202'), (28.945, 333.3125143683918, 'Acide Homovanillique')]
# AbrahamV-20200602
# [(9.439, 336.8412674886748, 'Acide 3OH-Propionique 20'), (11.945, 336.8412674886748, 'Acide Methylmalonique 20'), (16.673, 336.8412674886748, 'Acide Fumarique 20200722'), (18.463, 336.8412674886748, 'Acide Glutarique 2020072'), (19.264, 336.8412674886748, 'Acide 3CH3-Glutarique 20'), (21.59, 336.8412674886748, 'Acide Adipique 20200722'), (23.679, 336.8412674886748, 'Acide 2OH-Glutarique 202'), (28.905, 336.8412674886748, 'Acide Homovanillique')]
# AddaS-20200414
# [(9.41, 101.19929514728821, 'Acide 3OH-Propionique 20'), (11.889, 130.2215547152394, 'Acide Methylmalonique 20'), (16.673, 173.1588881587646, 'Acide Fumarique 20200722'), (18.463, 514.1756252565879, 'Acide Glutarique 2020072'), (19.089, 514.1756252565879, 'Acide 3CH3-Glutarique 20'), (21.59, 514.1756252565879, 'Acide Adipique 20200722'), (23.679, 514.1756252565879, 'Acide 2OH-Glutarique 202'), (28.905, 514.1756252565879, 'Acide Homovanillique')]

# %% [markdown]
# Vérification que les problèmes sont détectés

# %%
reload(tools)
n = 0
for i in data:
    result = i.ruleBasedCheck()
    
    if (result != []) :
        n+=1
print('nombre de données considérés anormales : ', n/len(data) * 100, ' %')
print(n)
# Out:
# nombre de données considérés anormales :  97.01986754966887  %
# 293

# %%
reload(tools)
problems = ['ChedadiA-20200715', 'AbaziM-20200210'] # le premier à méthylmalonique, le deuxième à pas propionique
number = 0
dt = tools.readAndAdaptDataFromCSV(PATH, problems[number])
print(dt.ruleBasedCheck())
dt.df.plot()
# Out:
# [(9.302, 421.99202566667634, 'Acide 3OH-Propionique 20'), (12.027, 421.99202566667634, 'Acide Methylmalonique 20'), (16.566, 421.99202566667634, 'Acide Fumarique 20200722'), (18.585, 421.99202566667634, 'Acide Glutarique 2020072'), (19.089, 421.99202566667634, 'Acide 3CH3-Glutarique 20'), (21.452, 421.99202566667634, 'Acide Adipique 20200722'), (23.679, 421.99202566667634, 'Acide 2OH-Glutarique 202'), (28.847, 421.99202566667634, 'Acide Homovanillique')]
